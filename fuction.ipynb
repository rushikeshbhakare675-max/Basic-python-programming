# %%
# fuction

# %%
# a fuction is a block of reuseable code thate perform

# %%
print("hallo")
# Out:
# hallo

# %%
len("python")
# Out:
# 6

# %%
# user defin fuction

# %%
# simple fuction

# %%
def greet():
    print("hallo wolde")
greet()
# Out:
# hallo wolde

# %%
# fuction with paramiter

# %%
def student(name,age):
    print(name,age)

student("rushi",20)
# Out:
# rushi 20

# %%
# fuction with retune value

# %%
def add(a,b):
    return a + b

result = add(10,30)  
print(result)
# Out:
# 40

# %%
def mul(a,b):
    return a * b
result =  mul(55,70)
print(result)
# Out:
# 3850

# %%
def add(a,b):
    return a + b

result = add(88,10)+mul(55,10)
print(result)
# Out:
# 648

# %%
# defolt paramiter

# %%
def greet(name="user"):
    print("hello",name)

greet()
greet("rushi")
# Out:
# hello user
# hello rushi

# %%
# type of argument

# %%
# positional argument

# %%
def show(name,age):
    print(name,age)

show("rushi",20)
# Out:
# rushi 20

# %%
# keyword argument

# %%
def name_age(name,age):
    return f"My name is{name} I am {age}year old."

show("rushi",19)
# Out:
# 'My name isrushi I an 19year old.'

# %%
def name_age_marke(name,age,marke):

# %%
# **kaearegs (key value)

# %%
def info(**data):
    print(data)

info(name="rahul",age=19)
# Out:
# {'name': 'rahul', 'age': 19}

# %%
def add(*nums):
    print(sum(nums))
    
add(10,20,30)
# Out:
# 60

# %%
# lambda fuction

# %%
add =
