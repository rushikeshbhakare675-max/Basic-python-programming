# %%
#a variabel is a name use tostore data

# %%
student_name="rushikesh"

# %%
print(student_name)
# Out:
# rushikesh

# %% [markdown]
# student_age=20

# %% [raw]
# print(student_age)

# %%
student_marks=88.9

# %%
print(student_marks)
# Out:
# 88.9

# %%
# printing with labels

# %%
name="rushikesh"

# %%
print("name=",name)
# Out:
# name= rushikesh

# %%
age="20"

# %%
print("age=",age)
# Out:
# age= 20

# %%
city='pune'

# %%
print("city=",city)
# Out:
# city= pune

# %%
#changing variabel values

# %%
course="python"

# %%
print("before changing:",course)
# Out:
# before changing: python

# %%
course="data science"

# %%
print("after changing:",course)
# Out:
# after changing: python

# %%
#multiple variable

# %%
x,y,z=100,200,300

# %%
print("x=",x)
# Out:
# x= 100

# %%
print("y=",y)
# Out:
# y= 200

# %%
print("z=",z)
# Out:
# z= 300

# %%
#same value to multiple variables

# %%
maths=science=english=90

# %%
maths
# Out:
# 90

# %%
science
# Out:
# 90

# %%
english
# Out:
# 90

# %%
# invalid variablse name

# %%
2name="rushikesh"
# Out:
#   Cell In[51], line 1
#     2name="rushikesh"
#     ^
# SyntaxError: invalid decimal literal

# %%
studant-name=rushi
# Out:
#   Cell In[52], line 1
#     studant-name=rushi
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?

# %%
full name="rushikesh s"
# Out:
#   Cell In[53], line 1
#     full name="rushikesh s"
#          ^
# SyntaxError: invalid syntax

# %%
class="python"
# Out:
#   Cell In[54], line 1
#     class="python"
#          ^
# SyntaxError: invalid syntax

# %%
#dinamik tiping

# %%
# python atomtically understands the data type

# %%
value=100

# %%
print(value)
# Out:
# 100

# %%
print(type(value))
# Out:
# <class 'int'>

# %%
value="python"

# %%
print(value)
# Out:
# python

# %%
print(type(value))
# Out:
# <class 'str'>

# %%
value=99.9

# %%
print(value)
# Out:
# 99.9

# %%
print(type(value))
# Out:
# <class 'float'>
